# %%
import pandas as pd

matches = pd.read_csv("../data/raw/arsenal_matches_2025_2026.csv")

matches.head()
# Out:
#                                                    Wk\tDay\tDate\tTime\tHome\tScore\tAway\tAttendance\tVenue\tReferee\tMatch Report\tNotes
# 1\tFri\t2025-08-15\t20:00\tLiverpool\t4–2\tBour...       315\tAnfield\tAnthony Taylor\tMatch Report\t
# 1\tSat\t2025-08-16\t12:30\tAston Villa\t0–0\tNe...      526\tVilla Park\tCraig Pawson\tMatch Report\t
# 1\tSat\t2025-08-16\t15:00\tBrighton\t1–1\tFulha...  478\tThe American Express Stadium\tSamuel Barr...
# 1\tSat\t2025-08-16\t15:00\tTottenham\t3–0\tBurn...  077\tTottenham Hotspur Stadium\tMichael Oliver...
# 1\tSat\t2025-08-16\t15:00\tSunderland\t3–0\tWes...  233\tStadium of Light\tRobert Jones\tMatch Rep...

# %%
matches.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 396 entries, 1	Fri	2025-08-15	20:00	Liverpool	4–2	Bournemouth	60 to 38	Sun	2026-05-24	16:00	West Ham	3–0	Leeds United	62
# Data columns (total 1 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Wk	Day	Date	Time	Home	Score	Away	Attendance	Venue	Referee	Match Report	Notes  380 non-null    str
# dtypes: str(1)
# memory usage: 6.2+ KB

# %%
print(open("../data/raw/arsenal_matches_2025_2026.csv", encoding="utf-8").readline())

# %%
print(open("../data/raw/arsenal_matches_2025_2026.csv", encoding="utf-8").readline())

# %%
import pandas as pd

print("Pandas fonctionne ✅")
# Out:
# Pandas fonctionne ✅
